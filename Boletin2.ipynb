# %% [markdown]
# #### Crea un programa que pida al usuario los datos de altura y base de un rectángulo. Tiene que tener al menos dos funciones en las que se les pase los datos de la altura y la base del rectángulo y devuelvan el área y el perímetro del mismo. Estos dos datos se tienen que mostrar al usuario por pantalla.

# %%
def calcularAreaRectángulo(ancho, alto):
    return ancho * alto
def calcularPerímetroRectángulo(ancho, alto):
    return 2 * (ancho + alto)


ancho = float(input("Ingrese el ancho del rectángulo: "))
alto = float(input("Ingrese el alto del rectángulo: "))

área = calcularAreaRectángulo(ancho, alto)
perímetro = calcularPerímetroRectángulo(ancho, alto)

print(f"El área del rectángulo es: {área}")
print(f"El perímetro del rectángulo es: {perímetro}")

# %% [markdown]
# #### Crea un programa que pida al usuario dos años. Tiene que tener al menos una función donde se les pase ambos números y se calcule la cantidad de años bisiestos que hay entre esos dos años. Por pantalla se tienen que mostrar esta cantidad y que años son los bisiestos. Nota: el usuario puede meter los años en cualquier orden, es decir, no tiene por qué ser primero el mayor o el menor

# %%
def esBisiesto(año1, año2):
    cantidadBisiestos = 0
    for año in range(año1, año2 + 1):
        if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0):
            cantidadBisiestos += 1
    return cantidadBisiestos
    

año1 = int(input("Ingresa un año:"))
año2 = int(input("Ingresa otro año:"))

print(f"Cantidad de años bisiestos entre {año1} y {año2}: {esBisiesto(año1, año2)}")

# %% [markdown]
# #### Crea un programa que pida al usuario que introduzca una cantidad aleatoria de palabras, de una en una. Si el usuario no quiere introducir más palabras, que introduzca “FIN”. El programa tiene que devolver todas las palabras ordenadas alfabéticamente, teniendo en cuenta las mayúsculas y las minúsculas. Se debe usar al menos una función.

# %%
def ordenarLista(lista):
    return sorted(lista)

palabras = []
palabra = ""
while palabra != "FIN":
    palabra = input("Ingresa una palabra (o 'FIN' para terminar): ")
    if palabra != "FIN":
        palabras.append(palabra)
palabras_ordenadas = ordenarLista(palabras)
print("Lista ordenada de palabras:", palabras_ordenadas)

# %% [markdown]
# #### Modifica el programa anterior para que el usuario no introduzca palabras repetidas.

# %%
def ordenarLista(lista):
    return sorted(lista)

palabras = []
palabra = ""
while palabra != "FIN":
    palabra = input("Ingresa una palabra (o 'FIN' para terminar): ")

    if palabra not in palabras:

        if palabra != "FIN":
            palabras.append(palabra)

    else:
        print(f"La palabra {palabra} ya fue ingresada. Intenta con otra.")


palabras_ordenadas = ordenarLista(palabras)
print("Lista ordenada de palabras:", palabras_ordenadas)

# %% [markdown]
# #### Crea un programa que pida al usuario que introduzca una cantidad de horas, el coste €/hora y el porcentaje de impuestos. Se tiene que mostrar por pantalla el sueldo bruto, los impuestos que se pagarían y el sueldo neto. Para cada parámetro utilizar una función.

# %%
def salario_bruto(cantidad_horas, tarifa_por_hora):
    return cantidad_horas * tarifa_por_hora

def salario_neto(cantidad_horas, tarifa_por_hora, porcentaje_impuestos):
    bruto = salario_bruto(cantidad_horas, tarifa_por_hora)
    impuestos = bruto * (porcentaje_impuestos / 100)
    return bruto - impuestos


cantidad_horas = int(input("Ingrese la cantidad de horas trabajadas en el mes: "))
tarifa_por_hora = float(input("Ingrese el coste por hora: "))
porcentaje_impuestos = float(input("Ingrese el porcentaje de impuestos a deducir: "))

bruto = salario_bruto(cantidad_horas, tarifa_por_hora)
neto = salario_neto(cantidad_horas, tarifa_por_hora, porcentaje_impuestos)

print(f"El salario bruto es: {bruto}")
print(f"El salario neto es: {neto}")

# %% [markdown]
# #### Crea un programa que pida al usuario que introduzca una cantidad de números aleatorios. Si el usuario no quiere introducir más números, que introduzca “-1”. El usuario no puede poder introducir datos que no sean números. Se mostrará por pantalla el promedio, el máximo y el mínimo de la lista de números introducidos. Se deben utilizar al menos 4 funciones.

# %%
def maximo(lista):
    if not lista:
        return None
    max_val = lista[0]
    for num in lista:
        if num > max_val:
            max_val = num
    return max_val

def minimo(lista):
    if not lista:
        return None
    min_val = lista[0]
    for num in lista:
        if num < min_val:
            min_val = num
    return min_val

def promedio(lista):
    if not lista:
        return None
    return sum(lista) / len(lista)


def main():
    n = 0
    lista_numeros = []
    while n!= -1:
        n = int(input("Ingresa un número entero (o -1 para terminar): "))
        if n != -1:
            lista_numeros.append(n)
    print(f"Lista de números: {lista_numeros}")
    print(f"Número máximo: {maximo(lista_numeros)}")
    print(f"Número mínimo: {minimo(lista_numeros)}")
    print(f"Promedio: {promedio(lista_numeros)}")
    
if __name__ == "__main__":
    main()

# %% [markdown]
# #### Crea un programa que pida al usuario que introduzca una contraseña. Se tiene que verificar si la contraseña es segura, para ello tiene que cumplir:
# Tiene que tener más de 8 caracteres.
#
# Tiene que tener al menos una mayúscula y una minúscula.
#
# Tiene que tener al menos un número.
#
# Tiene que tener un carácter especial como +, ), /…

# %%
def comprobarMayuscula(caracter):
    return caracter.isupper()

def comprobarMinuscula(caracter):
    return caracter.islower()

def comprobarNumero(caracter):
    return caracter.isdigit()

def comprobarCaracterEspecial(caracter):
    return caracter.isalnum() == False
    




contraseña = input("Introduce una contraseña: ")
for caracter in contraseña:
    if comprobarMayuscula(caracter):
        mayuscula_encontrada = True
    if comprobarMinuscula(caracter):
        minuscula_encontrada = True
    if comprobarNumero(caracter):
        numero_encontrado = True
    if comprobarCaracterEspecial(caracter):
        caracter_especial_encontrado = True
if (mayuscula_encontrada and minuscula_encontrada and
    numero_encontrado and caracter_especial_encontrado and
    len(contraseña) >= 8):
    print("Contraseña válida")
else:
    print("Contraseña inválida")

# %% [markdown]
# #### Crea un programa que pida al usuario que introduzca el nombre y la calificación de estudiantes. Cuando no quiera introducir más estudiantes, que ponga la palabra “FIN”. El programa tiene que detectar si se introduce algún alumno y nota iguales. Se tendrá que devolver el promedio de notas, el mejor estudiante y el peor estudiante. Se usarán al menos tres funciones.

# %%
dicc_estudiantes = {}

def agregar_estudiante():
    global dicc_estudiantes

    nombre = input("Ingrese el nombre del estudiante (o 'FIN' para terminar): ")
    
    if nombre == "FIN":
        return False
    
    nota = float(input(f"Ingrese la nota de {nombre}: "))
    dicc_estudiantes[nombre] = nota
    return True

def calcular_promedio():
    global dicc_estudiantes
    if not dicc_estudiantes:
        return 0
    return sum(dicc_estudiantes.values()) / len(dicc_estudiantes)

def obtener_mejor():
    global dicc_estudiantes
    if not dicc_estudiantes:
        return
    mejor_estudiante = max(dicc_estudiantes, key=dicc_estudiantes.get)
    return mejor_estudiante, dicc_estudiantes[mejor_estudiante]

def obtener_peor():
    global dicc_estudiantes
    if not dicc_estudiantes:
        return
    peor_estudiante = min(dicc_estudiantes, key=dicc_estudiantes.get)
    return peor_estudiante, dicc_estudiantes[peor_estudiante]

while True:
    if not agregar_estudiante():
        print("Promedio de notas:", calcular_promedio())
        mejor = obtener_mejor()
        print(f"Mejor estudiante: {mejor[0]} con nota {mejor[1]}")
        peor = obtener_peor()
        print(f"Peor estudiante: {peor[0]} con nota {peor[1]}")
        break

# %% [markdown]
# #### Crea un programa que gestione un inventario. Las opciones que se le muestran al usuario son:
# Agregar producto. El usuario podrá añadir productos proporcionando nombre, cantidad y precio.
# Actualizar producto. El usuario podrá modificar la cantidad de un producto.
# Valor del inventario de un producto. El usuario podrá verificar el valor total de un producto.
# Valor del inventario total. El usuario podrá verificar el valor total del inventario.
# Mostrar el inventario. Se mostrará el valor del inventario (nombre de los productos, cantidad y precio)
# Si el usuario no quiere realizar más acciones, se indicará y se terminará la ejecución.
# Cosas a tener en cuenta:
# Se deberá realizar usando diccionarios (con clave y valor)
# No se puede ni actualizar ni ver el valor del inventario de un producto si no existe dicho producto.
# Se pueden utilizar las funciones que se crean necesarias para que el código quede lo más limpio y funcional posible.

# %%
inventario = {}

def existe_producto(nombre):
    global inventario
    return nombre in inventario

def agregar_producto():
    global inventario

    nombre = input("Ingrese el nombre del producto (o 'FIN' para terminar): ")   
    cantidad = int(input(f"Ingrese la cantidad de {nombre}: "))
    if existe_producto(nombre):
        print(f"El producto {nombre} ya existe en el inventario.")
    else:
        precio = float(input(f"Ingrese el precio de {nombre}: "))
        inventario[nombre] = {"cantidad": cantidad, "precio": precio}
        print(f"Se ha agregado el producto {nombre} con cantidad {cantidad} y precio {precio}.")

def actualizar_producto():
    global inventario

    nombre = input("Ingrese el nombre del producto a actualizar (o 'FIN' para terminar): ")
    if not existe_producto(nombre):
        print(f"El producto {nombre} no existe en el inventario.")
    else:
        cantidad = int(input(f"Ingrese la nueva cantidad de {nombre}: "))
        precio = float(input(f"Ingrese el nuevo precio de {nombre}: "))
        inventario[nombre]["cantidad"] = cantidad
        inventario[nombre]["precio"] = precio
        print(f"Se ha actualizado el producto {nombre} con cantidad {cantidad} y precio {precio}.")


def valor_total_producto(nombre):
    global inventario
    if not existe_producto(nombre):
        return 0
    producto = inventario[nombre]
    return producto["cantidad"] * producto["precio"]


def valor_total_inventario():
    global inventario
    total = 0
    for nombre in inventario:
        total += valor_total_producto(nombre)
    return total


def mostrar_inventario():
    global inventario
    for nombre, datos in inventario.items():
        print(f"Producto: {nombre}, Cantidad: {datos['cantidad']}, Precio: {datos['precio']}, Valor Total: {valor_total_producto(nombre)}")
    print(f"Valor total del inventario: {valor_total_inventario()}")


while True:
    accion = int(input("1.Agregar \n 2.Actualizar un producto \n 3.Mostrar inventario \n 4.Finalizar (F)? ").upper())
